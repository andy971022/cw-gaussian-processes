# %%
n <- 1000
betas <- rbeta(n,4,1)

# %%
betas[1:5]
# Out:
# [1] 0.7710139 0.4836501 0.8505134 0.7685275 0.6077299

# %%
hist(betas)
# Out:
# Plot with title “Histogram of betas”

# %%
D <- 4

# %%
for(d in 1:D)
    {
    thetas <- rnorm(4,0,1)
    betas <- thetas[1] + thetas[2]*sinh(thetas[3]*asinh(betas)+thetas[4])
}

# %%
hist(betas)
# Out:
# Plot with title “Histogram of betas”

# %%
hist(vector)
# Out:
# Error in hist.default(vector): 'x' must be numeric
# Traceback:
#
# 1. hist(vector)
# 2. hist.default(vector)
# 3. stop("'x' must be numeric")

# %%
n <- 1000
betas <- rexp(n,5)

# %%
D <- 15

output <- betas

for(d in 1:D){ 
    output <- output + runif(1,0,1)*tanh(runif(1,0,1)*(betas+runif(1,0,10)))
}

# %%
hist(betas)
# Out:
# Plot with title “Histogram of betas”

# %%
hist(output)
# Out:
# Plot with title “Histogram of output”

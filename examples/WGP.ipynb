# %%
n <- 1000
betas <- rbeta(n,4,2)

# %%
D <- 3000

output <- betas

for(d in 1:D){ 
    output <- output + 1.01*tanh(1.01*(betas+1))
}

## f must be a monotonic function

# %%
hist(betas)
# Out:
# Plot with title “Histogram of betas”

# %%
hist(output)
# Out:
# Plot with title “Histogram of output”
